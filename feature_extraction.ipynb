# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mediapipe

import numpy as np
import cv2 as cv
import mediapipe as mp
import glob
import os
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.20-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.8.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.25.5)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Downloading mediapipe-0.10.20-cp310-cp310-manylinux_2_28_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 47.2 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.20 sounddevice-0.5.1

# %%
class FaceLandmarkGenerator:
  def __init__(self, mode=False, num_faces=2, min_detection_con=0.5, min_track_con=0.5):
    try:
      self.results = None
      self.mode = mode
      self.num_faces = num_faces
      self.min_detection_con = min_detection_con
      self.min_track_con = min_track_con

      self.mp_faceDetector = mp.solutions.face_mesh
      self.face_mesh = self.mp_faceDetector.FaceMesh(
        static_image_mode=self.mode,
        max_num_faces=self.num_faces,
        min_detection_confidence=self.min_detection_con,
        min_tracking_confidence=self.min_track_con
      )

      self.mp_draw = mp.solutions.drawing_utils
      self.drawSpecs = self.mp_draw.DrawingSpec(thickness=0.3, circle_radius=0.5)
    except Exception as e:
      raise RuntimeError(f"Failed to initialize FaceMeshGenerator: {str(e)}")

  def create_face_mesh(self, frame, draw=True):
    if frame is None:
      raise ValueError("Input frame cannot be None")

    try:
      frame_rgb = cv.cvtColor(frame, cv.COLOR_BGR2RGB)
      self.results = self.face_mesh.process(frame_rgb)
      landmarks_dict = {}

      if self.results.multi_face_landmarks:
        for face_lms in self.results.multi_face_landmarks:
          if draw:
            self.mp_draw.draw_landmarks(
              frame,
              face_lms,
              self.mp_faceDetector.FACEMESH_CONTOURS,
              self.drawSpecs,
              self.drawSpecs
            )
          ih, iw, _ = frame.shape
          for ID, lm in enumerate(face_lms.landmark):
            x, y = int(lm.x * iw), int(lm.y * ih)
            landmarks_dict[ID] = (x, y)

      return frame, landmarks_dict
    except Exception as e:
      raise RuntimeError(f"Error processing frame: {str(e)}")

# %%
class BlinkDetectionAndEARPlot:
    # Facial landmark indices for eyes
    RIGHT_EYE = [33, 7, 163, 144, 145, 153, 154, 155, 133, 173, 157, 158, 159, 160, 161, 246]
    LEFT_EYE = [362, 382, 381, 380, 374, 373, 390, 249, 263, 466, 388, 387, 386, 385, 384, 398]
    RIGHT_EYE_EAR = [33, 159, 158, 133, 153, 145]  # Points for EAR calculation
    LEFT_EYE_EAR = [362, 380, 374, 263, 386, 385]  # Points for EAR calculation

    def __init__(
        self,
        video_path,
        threshold,
        consec_frames
    ):
        self.generator = FaceLandmarkGenerator()
        self.video_path = video_path
        self.EAR_THRESHOLD = threshold
        self.CONSEC_FRAMES = consec_frames

        self.blink_counter = 0
        self.frame_counter = 0
        self.frame_number = 0
        self.ear_values = []
        self.frame_numbers = []
        self._init_video_saving()

    def _init_video_saving(self):
      self.out = None

    def eye_aspect_ratio(self, eye_landmarks, landmarks):
        A = np.linalg.norm(
            np.array(landmarks[eye_landmarks[1]])
            - np.array(landmarks[eye_landmarks[5]])
        )
        B = np.linalg.norm(
            np.array(landmarks[eye_landmarks[2]])
            - np.array(landmarks[eye_landmarks[4]])
        )
        C = np.linalg.norm(
            np.array(landmarks[eye_landmarks[0]])
            - np.array(landmarks[eye_landmarks[3]])
        )
        return (A + B) / (2.0 * C)

    def process_frame(self, frame):
        """
        Process a single frame to detect and analyze eyes.

        Returns:
            tuple: Processed frame and EAR value
        """
        frame, face_landmarks = self.generator.create_face_mesh(frame, draw=False)

        if not face_landmarks:
            return frame, None

        # Calculate EAR
        right_ear = self.eye_aspect_ratio(self.RIGHT_EYE_EAR, face_landmarks)
        left_ear = self.eye_aspect_ratio(self.LEFT_EYE_EAR, face_landmarks)
        ear = (right_ear + left_ear) / 2.0

        return frame, ear

    def process_video(self):
        """Process the entire video and detect blinks."""
        try:
            cap = cv.VideoCapture(self.video_path)
            if not cap.isOpened():
                return False
                raise IOError(f"Failed to open video: {self.video_path}")

            features_list = self._process_video_frames(cap)
            np_features_list = np.array(features_list)
            return np_features_list

        except Exception as e:
            print(f"An error occurred: {e}")
        finally:
            cap.release()
            if self.out:
                self.out.release()
            cv.destroyAllWindows()


    def _process_video_frames(self, cap):
        """Process individual frames from the video capture."""
        # Get video properties
        # w = int(cap.get(cv.CAP_PROP_FRAME_WIDTH))
        # h = int(cap.get(cv.CAP_PROP_FRAME_HEIGHT))
        # frame_count = int(cap.get(cv.CAP_PROP_POS_FRAMES))
        # fps = int(cap.get(cv.CAP_PROP_FPS))

        video_features = []
        previous_EAR = None
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            # frame = self._crop_out_face(frame.copy())
            # frame = cv.resize(frame, (128, 128))

            # Process frame and get EAR
            frame, ear = self.process_frame(frame)

            if ear is not None:
                if previous_EAR is None:
                    delta_EAR = 0
                else:
                    delta_EAR = ear - previous_EAR

                previous_EAR = ear
                blink_indicator = int(ear < self.EAR_THRESHOLD)

                self._update_blink_detection(ear)
                # print(f"Frame No.: {self.frame_number}, EAR: {ear}, Δ EAR: {delta_EAR}, Blink: {blink_indicator}")

                video_features.append([ear, delta_EAR, blink_indicator])

                # cv.imshow("Blink Counter", frame)

            if cv.waitKey(1) & 0xFF == ord("p"):
                break
        return video_features

    def _update_blink_detection(self, ear):
        """Update blink detection based on EAR value."""
        self.ear_values.append(ear)
        self.frame_numbers.append(self.frame_number)

        if ear < self.EAR_THRESHOLD:
            self.frame_counter += 1
        else:
            if self.frame_counter >= self.CONSEC_FRAMES:
                self.blink_counter += 1
            self.frame_counter = 0

        self.frame_number += 1

    def _crop_out_face(self, annotated_image):
        try:
            height, width, _ = annotated_image.shape
            mp_face_detection = mp.solutions.face_detection
            face_detection = mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5)
            result = face_detection.process(cv.cvtColor(annotated_image, cv.COLOR_BGR2RGB))

            if not result.detections:
                return annotated_image

            im_bbox = result.detections[0].location_data.relative_bounding_box
            np_annotated_image = np.array(annotated_image)
            xleft = im_bbox.xmin * width
            xtop = im_bbox.ymin*height
            xright = im_bbox.width * width + xleft
            xbottom = im_bbox.height*height + xtop

            xleft, xtop, xright, xbottom = int(xleft), int(xtop), int(xright), int(xbottom)

            return np_annotated_image[xtop:xbottom, xleft:xright]
        except Exception as e:
            print(f"Error in cropping image: {e}")

# %%
def faces_count(path):
    try:
        cap = cv.VideoCapture(path)
        if not cap.isOpened():
            raise IOError(f"Failed to open video: {path}")

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            annotated_image = frame.copy()

            # Initialize Face Detection
            mp_face_detection = mp.solutions.face_detection

            # For static images:
            face_detection = mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5)

            # Convert the BGR image to RGB before processing.
            result = face_detection.process(cv.cvtColor(annotated_image, cv.COLOR_BGR2RGB))

            return len(result.detections)

    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        cap.release()
        cv.destroyAllWindows()

# %%
def get_and_save_features(p, path, output_filename, idx):
    detected_faces = faces_count(p)
    if detected_faces != 1: return
    else:
        blink_counter = BlinkDetectionAndEARPlot(p, 0.294, 4)
        video_features = blink_counter.process_video()

        print(f"{idx} Video Processed | Features: ", video_features.shape, len(video_features))

        if not(os.path.exists(f"{path}{output_filename}")):
            os.makedirs(path, exist_ok=True)
            ds = {"ORE_MAX_GIORNATA": 5}
            np.save(os.path.join(path, output_filename), ds)

        np.save(f"{path}/{output_filename}", video_features)

# %%
def get_features_and_save_npy(video_paths, output_dir, output_files):
    for idx, p in enumerate(video_paths):
        _, tail = os.path.split(p)
        name = tail.split(".")[0]

        np_path = output_dir + f"{name}.npy"
        output_filename = f"{name}.npy"
        path = output_dir

        if np_path in output_files:
            print(f"{idx} => File missed: ", np_path)
        else:
            get_and_save_features(p, path, output_filename, idx)
            print(f"{idx} => File processed: ", p)

# %%
fake_dir = "/content/drive/MyDrive/Dissertation/dataset/manipulated_sequences"
orig_dir = "/content/drive/MyDrive/Dissertation/dataset/original_sequences"

np_fake_dir_path = "/content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0"
np_orig_dir_path = "/content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/1"

np_fake_paths = np.array(glob.glob(np_fake_dir_path + "/*.npy"))
np_orig_paths = np.array(glob.glob(np_orig_dir_path + "/*.npy"))

print("np_fake_paths: ", len(np_fake_paths), np_fake_paths.shape)
print("np_orig_paths: ", len(np_orig_paths), np_orig_paths.shape)

fake_paths = glob.glob(fake_dir + "/*/*/*/*.mp4")
orig_paths = glob.glob(orig_dir + "/*/*/*/*.mp4")
print("fake_paths: ", len(fake_paths))
print("orig_dir: ", len(orig_paths))
# Out:
# np_fake_paths:  3173 (3173,)
# np_orig_paths:  1157 (1157,)
# fake_paths:  8067
# orig_dir:  1363

# %%
all_video_features = []
all_video_targets = []

get_features_and_save_npy(fake_paths, f"/content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/", np_fake_paths)
# get_features_and_save_npy(orig_paths, f"/content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/1/", np_orig_paths)
print("All fake videos processed........")
# Out:
# 0 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_01__talking_angry_couch__02HILKYO.npy
# 1 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_18__walking_down_street_outside_angry__UMEX6HWU.npy
# 2 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_12__exit_phone_room__D7G6YJON.npy
# 3 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/23_22__walk_down_hall_angry__J671JKCH.npy
# 4 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_12__talking_angry_couch__BFBNM8FR.npy
# 5 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_09__hugging_happy__RCETIXYL.npy
# 6 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_11__outside_talking_still_laughing__P08VGHTA.npy
# 7 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/10_19__walking_outside_cafe_disgusted__BVVPN5D5.npy
# 8 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_07__hugging_happy__9Z2MLKVX.npy
# 9 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_21__kitchen_still__YCSEBZO4.npy
# 10 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_14__podium_speech_happy__KMQ3AW6A.npy
# 11 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_14__walking_outside_cafe_disgusted__N0WM4GSV.npy
# 12 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_07__talking_against_wall__O4SXNLRL.npy
# 13 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/22_24__kitchen_still__7E3GY85F.npy
# 14 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_03__talking_angry_couch__JZUXXFRB.npy
# 15 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_03__podium_speech_happy__UEC1BI8E.npy
# 16 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_18__secret_conversation__A5A1Q467.npy
# 17 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_25__walking_and_outside_surprised__Z7FQ69VP.npy
# 18 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_25__walking_down_street_outside_angry__41UL3HO6.npy
# 19 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_26__kitchen_pan__C3K20JOL.npy
# 20 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_20__hugging_happy__C50CSOEX.npy
# 21 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_09__kitchen_still__JEELOMN2.npy
# 22 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_07__walking_and_outside_surprised__KAG65PEE.npy
# 23 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/04_13__talking_angry_couch__00T3UYOR.npy
# 24 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_06__exit_phone_room__QRCD27P8.npy
# 25 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/22_10__outside_talking_still_laughing__J2HR5HKH.npy
# 26 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/08_28__walk_down_hall_angry__GGCUYQA4.npy
# 27 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_23__podium_speech_happy__D1K19NUP.npy
# 28 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/11_20__secret_conversation__B2H95QXV.npy
# 29 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/23_19__talking_angry_couch__D1K19NUP.npy
# 30 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_26__walking_down_street_outside_angry__XKQAYTLI.npy
# 31 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_02__outside_talking_pan_laughing__I8G2LWD1.npy
# 32 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_18__kitchen_still__UMEX6HWU.npy
# 33 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_20__walk_down_hall_angry__B014BKVO.npy
# 34 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/11_01__kitchen_pan__WIZ7GKOD.npy
# 35 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_20__talking_angry_couch__FW94AIMJ.npy
# 36 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_04__talking_against_wall__00T3UYOR.npy
# 37 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_13__exit_phone_room__3GQ49P2J.npy
# 38 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_14__hugging_happy__VOX29AK0.npy
# 39 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_27__kitchen_still__3RH5PR6S.npy
# 40 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_04__secret_conversation__6J3ZFEJQ.npy
# 41 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_12__kitchen_still__RK17XFJ9.npy
# 42 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_15__walking_down_street_outside_angry__X0EIIJF7.npy
# 43 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_13__outside_talking_still_laughing__BVZGDFD8.npy
# 44 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_26__walking_down_street_outside_angry__L5BVR5L9.npy
# 45 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_03__walking_and_outside_surprised__38OVCK3X.npy
# 46 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/27_25__hugging_happy__1KU29EUL.npy
# 47 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_03__walk_down_hall_angry__7JPPCV50.npy
# 48 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_11__talking_against_wall__P06JKA75.npy
# 49 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_18__kitchen_still__22UBC0BS.npy
# 50 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_25__outside_talking_pan_laughing__IKMKYKPG.npy
# 51 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_25__talking_angry_couch__ODAQ7BZL.npy
# 52 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_07__kitchen_pan__1MSOAVLL.npy
# 53 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_13__walking_down_indoor_hall_disgust__GBYWJW06.npy
# 54 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_01__secret_conversation__480LQD1C.npy
# 55 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/28_16__secret_conversation__ZA8XJIE9.npy
# 56 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_18__walking_and_outside_surprised__A5A1Q467.npy
# 57 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_11__kitchen_still__GNK9UR8K.npy
# 58 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_09__outside_talking_pan_laughing__3VP8836C.npy
# 59 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_20__walk_down_hall_angry__B0X1CGG2.npy
# 60 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/22_10__walk_down_hall_angry__G48B2EQ2.npy
# 61 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_09__meeting_serious__9TDCEK1Q.npy
# 62 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_06__walking_outside_cafe_disgusted__NMGYPBXE.npy
# 63 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_01__walking_and_outside_surprised__02HILKYO.npy
# 64 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/04_18__secret_conversation__6J3ZFEJQ.npy
# 65 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_02__walking_and_outside_surprised__N864L40U.npy
# 66 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_07__kitchen_pan__34PVT42V.npy
# 67 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/23_19__walking_outside_cafe_disgusted__D1K19NUP.npy
# 68 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_20__walking_down_street_outside_angry__HG1S0KHA.npy
# 69 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_04__walking_outside_cafe_disgusted__0XUW13RW.npy
# 70 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_15__walking_down_street_outside_angry__YDX3GHFS.npy
# 71 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_03__podium_speech_happy__CDSNLDQ8.npy
# 72 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_04__walking_down_street_outside_angry__5Y31RZP8.npy
# 73 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_26__talking_against_wall__AI94QW74.npy
# 74 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_25__outside_talking_pan_laughing__ODAQ7BZL.npy
# 75 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_02__podium_speech_happy__XNJIS4S3.npy
# 76 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_14__podium_speech_happy__P9QFO50U.npy
# 77 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_09__outside_talking_still_laughing__8DTEGQ54.npy
# 78 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_09__podium_speech_happy__JEELOMN2.npy
# 79 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/27_25__walk_down_hall_angry__ZTV6TUQ9.npy
# 80 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_03__outside_talking_pan_laughing__8DTEGQ54.npy
# 81 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_01__outside_talking_pan_laughing__03X7CELV.npy
# 82 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_18__podium_speech_happy__SEGFKFJG.npy
# 83 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_03__outside_talking_pan_laughing__32DBR8L4.npy
# 84 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_09__walk_down_hall_angry__YP7MGDQ6.npy
# 85 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_02__secret_conversation__3IUBEKCT.npy
# 86 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_07__podium_speech_happy__UH60ROEK.npy
# 87 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_18__kitchen_still__B95S4G6F.npy
# 88 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/05_16__kitchen_pan__94435UY3.npy
# 89 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_07__walking_down_street_outside_angry__0VN0A2T3.npy
# 90 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/23_22__kitchen_pan__W9MT3Q5K.npy
# 91 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/08_17__outside_talking_still_laughing__JZYRLJ8T.npy
# 92 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_02__kitchen_pan__6KUOFMZW.npy
# 93 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_10__walking_down_street_outside_angry__QNZIMEJH.npy
# 94 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_09__outside_talking_still_laughing__9TDCEK1Q.npy
# 95 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/22_24__talking_against_wall__XL557XC6.npy
# 96 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_15__walking_down_street_outside_angry__02HILKYO.npy
# 97 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/22_10__walking_and_outside_surprised__G48B2EQ2.npy
# 98 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/27_15__kitchen_pan__2ERUWYH8.npy
# 99 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_14__hugging_happy__B014BKVO.npy
# 100 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_26__kitchen_pan__HEKDCIHW.npy
# 101 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/04_21__secret_conversation__PRCQUMY8.npy
# 102 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_15__outside_talking_pan_laughing__QRCD27P8.npy
# 103 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_24__secret_conversation__NPZW2Z9L.npy
# 104 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/10_22__walk_down_hall_angry__C1U7OY5M.npy
# 105 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_04__secret_conversation__WX836VLY.npy
# 106 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_14__walk_down_hall_angry__N0WM4GSV.npy
# 107 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/04_18__walking_outside_cafe_disgusted__6J3ZFEJQ.npy
# 108 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_25__podium_speech_happy__0UFFR3U1.npy
# 109 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_21__outside_talking_pan_laughing__03X7CELV.npy
# 110 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/16_17__walking_down_indoor_hall_disgust__S7UMSIQV.npy
# 111 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_06__exit_phone_room__H9445M6R.npy
# 112 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_13__walking_and_outside_surprised__SIA5P4HL.npy
# 113 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_26__talking_against_wall__UMEX6HWU.npy
# 114 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_20__exit_phone_room__FZHCQNKV.npy
# 115 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/16_05__walk_down_hall_angry__O56DDU3S.npy
# 116 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_12__outside_talking_pan_laughing__9D2ZHEKW.npy
# 117 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_07__walking_outside_cafe_disgusted__PAE9HCA8.npy
# 118 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_26__exit_phone_room__U5ELHUN5.npy
# 119 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_24__kitchen_still__0ZFOV5ZE.npy
# 120 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/04_07__kitchen_still__M2NBCLFR.npy
# 121 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/23_10__secret_conversation__CU6SNBFZ.npy
# 122 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_26__exit_phone_room__FGNGC2GT.npy
# 123 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_12__walking_outside_cafe_disgusted__FQE07ND1.npy
# 124 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_27__outside_talking_still_laughing__S2YCUY48.npy
# 125 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_25__outside_talking_still_laughing__Z7FQ69VP.npy
# 126 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_03__kitchen_pan__5C1OMK8W.npy
# 127 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_03__kitchen_pan__1IXGY2FK.npy
# 128 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/27_26__talking_angry_couch__IE9N0ZI9.npy
# 129 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_03__hugging_happy__W3MXGEU9.npy
# 130 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_02__outside_talking_still_laughing__MCRFMYAE.npy
# 131 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_15__kitchen_still__I8G2LWD1.npy
# 132 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/17_16__outside_talking_pan_laughing__S7UMSIQV.npy
# 133 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_15__outside_talking_still_laughing__SB6PMCO0.npy
# 134 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_15__hugging_happy__OMLZILK3.npy
# An error occurred: object of type 'NoneType' has no len()
# 135 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/23_19__kitchen_pan__WHQ1229T.mp4
# 136 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_13__talking_angry_couch__AROBAY8R.npy
# 137 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_15__hugging_happy__QRCD27P8.npy
# 138 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_09__walking_outside_cafe_disgusted__3GQ49P2J.npy
# 139 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_06__podium_speech_happy__ZFRX9RKW.npy
# 140 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/08_17__talking_against_wall__ISS1V0B1.npy
# 141 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_18__outside_talking_still_laughing__V5VHLCOW.npy
# 142 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_03__secret_conversation__0O9TTCJT.npy
# 143 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/22_19__walking_and_outside_surprised__VK6BF5NV.mp4
# 144 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/10_23__outside_talking_still_laughing__GYY4VANY.npy
# An error occurred: object of type 'NoneType' has no len()
# 145 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/25_20__exit_phone_room__M86GQTHK.mp4
# An error occurred: object of type 'NoneType' has no len()
# 146 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/26_06__walking_outside_cafe_disgusted__L5BVR5L9.mp4
# 147 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_26__podium_speech_happy__1UEDQ3GY.npy
# 148 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_07__outside_talking_still_laughing__0VN0A2T3.npy
# 149 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_13__kitchen_still__BFH4F0N8.npy
# 150 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_26__walk_down_hall_angry__L5BVR5L9.npy
# 151 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_02__hugging_happy__1JCLEEBQ.npy
# 152 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/11_13__podium_speech_happy__XXKQ4XM0.npy
# 153 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/01_20__walking_and_outside_surprised__6UBMLXK3.mp4
# 154 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/11_03__kitchen_still__P08VGHTA.npy
# 155 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_18__kitchen_still__OXMEEFUQ.npy
# 156 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_26__outside_talking_still_laughing__L5BVR5L9.npy
# 157 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_27__podium_speech_happy__UGO2181S.npy
# 158 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/01_20__walking_and_outside_surprised__OTGHOG4Z.mp4
# 159 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/27_06__walking_and_outside_surprised__VN14WY2N.mp4
# 160 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_01__walking_down_street_outside_angry__SJZRV69J.npy
# 161 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_02__walking_down_street_outside_angry__37DH75GQ.npy
# 162 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_03__podium_speech_happy__IFSURI9X.npy
# 163 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_27__exit_phone_room__RC9KATOO.npy
# 164 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_02__secret_conversation__QH3Y0IG0.mp4
# 165 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/27_13__talking_against_wall__A1OSUJE9.npy
# An error occurred: object of type 'NoneType' has no len()
# 166 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_11__outside_talking_pan_laughing__P08VGHTA.mp4
# 167 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_13__hugging_happy__EV1V4ZQV.npy
# An error occurred: object of type 'NoneType' has no len()
# 168 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/26_03__outside_talking_pan_laughing__WBSXBL82.mp4
# 169 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_07__podium_speech_happy__FGNGC2GT.npy
# 170 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/11_03__podium_speech_happy__P08VGHTA.npy
# 171 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/07_13__secret_conversation__RVQCPCJF.mp4
# 172 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/23_19__hugging_happy__WHQ1229T.npy
# 173 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_03__walking_outside_cafe_disgusted__WBSXBL82.npy
# 174 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_09__kitchen_still__N9CWME71.npy
# 175 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/15_03__walking_and_outside_surprised__OY4I7ZU8.mp4
# 176 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_15__outside_talking_still_laughing__4SO1CSAM.npy
# 177 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_21__kitchen_still__IRKML4J0.npy
# 178 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_02__podium_speech_happy__9TDCEK1Q.npy
# 179 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_14__walk_down_hall_angry__PLCQJM81.npy
# An error occurred: object of type 'NoneType' has no len()
# 180 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/09_02__kitchen_pan__HIH8YA82.mp4
# 181 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/11_18__kitchen_still__TRJUIS24.npy
# An error occurred: object of type 'NoneType' has no len()
# 182 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/12_02__outside_talking_pan_laughing__9D2ZHEKW.mp4
# An error occurred: object of type 'NoneType' has no len()
# 183 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/20_26__outside_talking_pan_laughing__01OJA93K.mp4
# 184 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_23__walk_down_hall_angry__H4SUVFTL.npy
# An error occurred: object of type 'NoneType' has no len()
# 185 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/02_27__outside_talking_pan_laughing__QW05XUUZ.mp4
# 186 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/26_04__walk_down_hall_angry__WX836VLY.mp4
# 187 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_06__podium_speech_happy__KIWCEATU.npy
# 188 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_15__walking_and_outside_surprised__OY4I7ZU8.mp4
# 189 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/24_22__talking_angry_couch__7E3GY85F.mp4
# 190 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_01__talking_angry_couch__YVGY8LOK.npy
# 191 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_21__hugging_happy__CRGVSDBI.npy
# 192 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/27_25__walking_and_outside_surprised__1KU29EUL.mp4
# 193 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_14__walking_down_street_outside_angry__B014BKVO.npy
# 194 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_09__talking_against_wall__LPT427RY.npy
# 195 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_26__meeting_serious__WBSXBL82.mp4
# 196 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/11_07__kitchen_still__H1YF1M1B.npy
# An error occurred: object of type 'NoneType' has no len()
# 197 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/18_03__outside_talking_pan_laughing__8HNSXOBW.mp4
# 198 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/23_19__talking_angry_couch__F7U8UY7V.mp4
# 199 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/28_16__exit_phone_room__OANAQYD5.npy
# 200 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_02__talking_angry_couch__YVGY8LOK.npy
# 201 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/02_27__walking_and_outside_surprised__QW05XUUZ.mp4
# 202 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_15__outside_talking_still_laughing__RNHLLKSQ.npy
# 203 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_03__podium_speech_happy__22UBC0BS.npy
# 204 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_14__secret_conversation__KJ221YN0.mp4
# An error occurred: object of type 'NoneType' has no len()
# 205 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_14__kitchen_pan__B1CG25H1.mp4
# 206 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/05_17__talking_against_wall__YTJYYDO9.npy
# 207 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_02__podium_speech_happy__N864L40U.npy
# 208 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/23_22__secret_conversation__AKZRL2QD.npy
# 209 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_20__hugging_happy__43KAHOT2.npy
# 210 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_02__talking_against_wall__GH8TGTBS.npy
# 211 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_13__kitchen_still__2994SNXH.npy
# 212 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_02__secret_conversation__OXMEEFUQ.npy
# 213 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_18__secret_conversation__32DBR8L4.mp4
# 214 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/24_19__kitchen_still__RKQTC50P.npy
# 215 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/21_14__walking_and_outside_surprised__N0WM4GSV.mp4
# 216 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_07__hugging_happy__O4SXNLRL.npy
# 217 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_14__walking_and_outside_surprised__H0VQHGS3.mp4
# 218 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_15__walking_outside_cafe_disgusted__X0EIIJF7.npy
# 219 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_13__outside_talking_still_laughing__2TM4IFSF.npy
# 220 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_09__secret_conversation__8DTEGQ54.mp4
# An error occurred: object of type 'NoneType' has no len()
# 221 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/18_15__outside_talking_pan_laughing__V5VHLCOW.mp4
# 222 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_25__talking_angry_couch__NFBISHIN.npy
# An error occurred: Failed to open video: /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/14_07__walking_down_indoor_hall_disgust__P9QFO50U.mp4
# 223 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/14_07__walking_down_indoor_hall_disgust__P9QFO50U.mp4
# 224 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/24_22__talking_against_wall__7E3GY85F.npy
# 225 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_20__walk_down_hall_angry__KV6Q7D6C.npy
# 226 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_26__secret_conversation__ILLP29ZH.npy
# 227 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_14__outside_talking_still_laughing__01YF7VQM.npy
# 228 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_21__exit_phone_room__JDPD580N.npy
# 229 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/12_20__secret_conversation__VD7BCF1U.mp4
# An error occurred: object of type 'NoneType' has no len()
# 230 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/08_16__kitchen_pan__8Q7JCS95.mp4
# An error occurred: object of type 'NoneType' has no len()
# 231 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/27_25__walking_down_street_outside_angry__ZTV6TUQ9.mp4
# 232 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/23_24__walking_down_indoor_hall_disgust__MDSDXSNU.mp4
# An error occurred: object of type 'NoneType' has no len()
# 233 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/11_04__outside_talking_pan_laughing__JRQWOV1G.mp4
# 234 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_20__talking_against_wall__R7SPX6OK.npy
# 235 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/23_24__walking_down_street_outside_angry__YR5OVD4S.npy
# 236 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_13__outside_talking_still_laughing__CJALTDKT.npy
# 237 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_25__outside_talking_still_laughing__ODAQ7BZL.npy
# 238 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_11__podium_speech_happy__DBSWZLXL.npy
# An error occurred: object of type 'NoneType' has no len()
# 239 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/11_26__outside_talking_pan_laughing__ALJ0OHNM.mp4
# 240 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_14__secret_conversation__A5A1Q467.npy
# 241 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/22_10__walk_down_hall_angry__PUJR4HJ1.npy
# 242 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_11__hugging_happy__C8C4FW99.npy
# 243 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/15_13__walking_down_indoor_hall_disgust__X0EIIJF7.mp4
# 244 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_12__kitchen_pan__BFBNM8FR.npy
# An error occurred: object of type 'NoneType' has no len()
# 245 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/22_10__outside_talking_pan_laughing__1TXK09OY.mp4
# 246 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_20__walk_down_hall_angry__43KAHOT2.npy
# 247 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_03__exit_phone_room__OY4I7ZU8.npy
# 248 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_01__walking_down_street_outside_angry__P70H1JB0.npy
# 249 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_25__exit_phone_room__RSCD7KXO.npy
# 250 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_01__exit_phone_room__480LQD1C.npy
# 251 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/22_10__walking_and_outside_surprised__8YQ2EUQP.mp4
# 252 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_02__exit_phone_room__MZWH8ATN.npy
# 253 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_07__walking_down_street_outside_angry__K7KXUHMU.npy
# 254 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/18_03__walk_down_hall_angry__22UBC0BS.mp4
# An error occurred: object of type 'NoneType' has no len()
# 255 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/26_20__walking_outside_cafe_disgusted__C8GN41DU.mp4
# 256 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_24__walking_down_street_outside_angry__GNHYZ84G.npy
# 257 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_03__kitchen_still__BKLOCI1M.npy
# 258 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_03__exit_phone_room__N72YE748.npy
# 259 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_12__talking_against_wall__HEKDCIHW.npy
# 260 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_18__walking_and_outside_surprised__22UBC0BS.mp4
# 261 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/12_25__walking_and_outside_surprised__G26LG5N7.mp4
# 262 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_14__exit_phone_room__B014BKVO.npy
# 263 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_06__hugging_happy__1IXGY2FK.npy
# An error occurred: object of type 'NoneType' has no len()
# 264 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/17_05__kitchen_pan__C4VHXZFY.mp4
# 265 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/27_02__podium_speech_happy__6GC9HY9J.npy
# 266 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_18__walk_down_hall_angry__C9VUQS9O.npy
# 267 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_02__talking_angry_couch__U6MDWIHG.npy
# 268 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_15__walk_down_hall_angry__N0SRODQD.npy
# An error occurred: object of type 'NoneType' has no len()
# 269 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/15_18__kitchen_pan__V5VHLCOW.mp4
# 270 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_15__talking_against_wall__I8G2LWD1.npy
# 271 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_03__exit_phone_room__480LQD1C.npy
# 272 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_01__hugging_happy__6UBMLXK3.npy
# An error occurred: object of type 'NoneType' has no len()
# 273 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/27_07__outside_talking_pan_laughing__LEVU87KC.mp4
# 274 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/05_16__hugging_happy__4MEM6YNQ.npy
# 275 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/27_13__hugging_happy__A1OSUJE9.npy
# 276 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_07__outside_talking_still_laughing__KM6M2TBT.npy
# 277 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/24_22__talking_against_wall__XL557XC6.npy
# 278 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_03__talking_angry_couch__ISF9SP4G.npy
# 279 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/04_26__talking_angry_couch__MS2MLJP1.npy
# 280 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/28_08__podium_speech_happy__5DCAESDA.npy
# An error occurred: object of type 'NoneType' has no len()
# 281 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/24_23__kitchen_pan__YR5OVD4S.mp4
# 282 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/05_16__talking_against_wall__U9WZI5LK.npy
# An error occurred: object of type 'NoneType' has no len()
# 283 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/21_11__kitchen_pan__N6YQW2AP.mp4
# An error occurred: object of type 'NoneType' has no len()
# 284 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/15_14__outside_talking_pan_laughing__OMLZILK3.mp4
# 285 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/22_10__kitchen_still__1TXK09OY.npy
# An error occurred: object of type 'NoneType' has no len()
# 286 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/11_18__outside_talking_pan_laughing__KLKJ9FPE.mp4
# 287 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_03__outside_talking_still_laughing__F0YYEA5W.npy
# 288 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_13__talking_against_wall__2TM4IFSF.npy
# 289 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_11__walking_down_street_outside_angry__B2H95QXV.npy
# 290 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_15__walk_down_hall_angry__KM6M2TBT.npy
# 291 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_01__kitchen_still__ZMEJ535O.npy
# 292 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/21_07__walking_down_indoor_hall_disgust__MKU99DVX.mp4
# 293 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_15__podium_speech_happy__02HILKYO.npy
# 294 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_18__kitchen_pan__XJ76YU5A.npy
# 295 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_07__walking_outside_cafe_disgusted__1H07DFQJ.npy
# An error occurred: object of type 'NoneType' has no len()
# 296 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/25_13__outside_talking_pan_laughing__PBM86HKZ.mp4
# An error occurred: object of type 'NoneType' has no len()
# 297 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/27_02__kitchen_pan__B3XHKO27.mp4
# An error occurred: object of type 'NoneType' has no len()
# 298 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/13_20__kitchen_pan__4SAX54BT.mp4
# 299 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_06__talking_against_wall__DEA1TCLN.npy
# An error occurred: object of type 'NoneType' has no len()
# 300 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/26_14__walking_outside_cafe_disgusted__ILLP29ZH.mp4
# An error occurred: object of type 'NoneType' has no len()
# 301 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/27_02__walking_down_street_outside_angry__XFSH3BW7.mp4
# 302 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_07__secret_conversation__P9QFO50U.npy
# 303 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_18__talking_against_wall__UMEX6HWU.npy
# 304 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_02__kitchen_still__I8G2LWD1.npy
# 305 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_13__kitchen_pan__CP5HFV3K.npy
# 306 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/06_25__walking_and_outside_surprised__3QQBVBYN.mp4
# An error occurred: object of type 'NoneType' has no len()
# 307 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/17_16__outside_talking_pan_laughing__EWJJTZHY.mp4
# 308 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_01__outside_talking_still_laughing__TNI7KUZ6.npy
# 309 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_11__talking_against_wall__Z5MZ8PP7.npy
# 310 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_01__secret_conversation__6UBMLXK3.npy
# 311 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_21__walk_down_hall_angry__ZCB5OMEW.npy
# An error occurred: object of type 'NoneType' has no len()
# 312 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/09_07__outside_talking_pan_laughing__N9CWME71.mp4
# An error occurred: object of type 'NoneType' has no len()
# 313 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/25_15__walking_down_street_outside_angry__BXVA6VQB.mp4
# 314 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_15__talking_against_wall__QRCD27P8.npy
# 315 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/16_17__walk_down_hall_angry__EWJJTZHY.npy
# 316 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_21__podium_speech_happy__NFBISHIN.npy
# 317 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_14__outside_talking_still_laughing__IRKML4J0.npy
# 318 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_26__walking_down_street_outside_angry__JHMUZFIJ.npy
# 319 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/18_03__walking_outside_cafe_disgusted__UEC1BI8E.npy
# 320 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/15_02__walking_and_outside_surprised__I8G2LWD1.mp4
# 321 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/27_06__walking_outside_cafe_disgusted__S3T7SK9O.npy
# 322 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_25__podium_speech_happy__G26LG5N7.npy
# 323 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_14__walk_down_hall_angry__ILLP29ZH.npy
# 324 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_23__secret_conversation__H4SUVFTL.npy
# 325 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_14__walking_down_street_outside_angry__N0WM4GSV.npy
# ...
# 1894 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_03__walking_outside_cafe_disgusted__GZNLO4X9.npy
# 1895 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_25__talking_against_wall__NFBISHIN.npy
# 1896 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_21__walking_down_street_outside_angry__WBPEX4CU.npy
# 1897 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_12__outside_talking_still_laughing__D7G6YJON.npy
# 1898 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/11_04__walking_outside_cafe_disgusted__SXI772ZL.npy
# 1899 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/04_12__kitchen_pan__B6YJ9IW1.npy
# 1900 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/11_21__exit_phone_room__1EAA3MPV.npy
# 1901 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/10_22__exit_phone_room__8YQ2EUQP.npy
# 1902 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_24__talking_against_wall__QD5K7BP2.npy
# 1903 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_14__talking_angry_couch__B014BKVO.npy
# 1904 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/10_22__exit_phone_room__C1U7OY5M.npy
# An error occurred: object of type 'NoneType' has no len()
# 1905 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/24_22__walking_down_street_outside_angry__7E3GY85F.mp4
# An error occurred: object of type 'NoneType' has no len()
# 1906 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/07_15__outside_talking_pan_laughing__UGGRZJ60.mp4
# 1907 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_07__outside_talking_still_laughing__K7KXUHMU.npy
# 1908 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/22_10__kitchen_still__8YQ2EUQP.npy
# 1909 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_01__walk_down_hall_angry__YVGY8LOK.npy
# 1910 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_06__kitchen_still__HZAXM70B.npy
# 1911 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_09__kitchen_still__NDMHWBT1.npy
# 1912 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_13__outside_talking_still_laughing__N8IGC93J.npy
# An error occurred: object of type 'NoneType' has no len()
# 1913 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/14_15__outside_talking_pan_laughing__OMLZILK3.mp4
# 1914 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_04__outside_talking_still_laughing__8CH7R4LW.npy
# 1915 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_26__secret_conversation__C8GN41DU.npy
# 1916 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/04_26__talking_against_wall__WX836VLY.npy
# An error occurred: object of type 'NoneType' has no len()
# 1917 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/04_02__walk_down_hall_angry__8CH7R4LW.mp4
# 1918 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_07__talking_against_wall__F0YYEA5W.npy
# 1919 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/20_07__talking_against_wall__KV6Q7D6C.npy
# An error occurred: object of type 'NoneType' has no len()
# 1920 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/02_27__kitchen_pan__UGO2181S.mp4
# 1921 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_07__hugging_happy__IFSURI9X.npy
# 1922 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_25__hugging_happy__IKMKYKPG.npy
# 1923 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_07__talking_against_wall__WPT3Z2KN.npy
# An error occurred: object of type 'NoneType' has no len()
# 1924 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/18_21__outside_talking_pan_laughing__PQFTWVRQ.mp4
# An error occurred: object of type 'NoneType' has no len()
# 1925 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/02_27__kitchen_pan__B3XHKO27.mp4
# 1926 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_27__outside_talking_still_laughing__YQX5Z8GN.npy
# 1927 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_20__exit_phone_room__XWMKFMF6.npy
# 1928 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/23_22__outside_talking_still_laughing__W9MT3Q5K.npy
# 1929 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_09__hugging_happy__6TEK3ZX0.npy
# 1930 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/10_23__exit_phone_room__W4BDINQ5.npy
# 1931 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_15__exit_phone_room__MCRFMYAE.npy
# 1932 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_09__walking_outside_cafe_disgusted__5041ODBN.npy
# 1933 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/21_15__hugging_happy__87WSBJP3.npy
# 1934 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/11_01__outside_talking_still_laughing__18HYCC8C.npy
# An error occurred: object of type 'NoneType' has no len()
# 1935 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/03_01__kitchen_pan__JZUXXFRB.mp4
# 1936 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_09__hugging_happy__9TDCEK1Q.npy
# 1937 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_26__talking_angry_couch__1ZRIYSSU.npy
# An error occurred: object of type 'NoneType' has no len()
# 1938 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/09_13__outside_talking_pan_laughing__TG55WJXX.mp4
# 1939 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_02__talking_angry_couch__J1W9R0NG.npy
# 1940 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_02__exit_phone_room__1JCLEEBQ.npy
# 1941 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/12_15__secret_conversation__RK17XFJ9.mp4
# An error occurred: object of type 'NoneType' has no len()
# 1942 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/26_06__walking_down_street_outside_angry__L5BVR5L9.mp4
# 1943 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_06__outside_talking_pan_laughing__3QQBVBYN.npy
# 1944 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/27_02__exit_phone_room__6GC9HY9J.npy
# 1945 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/05_28__walking_down_street_outside_angry__U9LRLJ6N.npy
# 1946 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/08_28__podium_speech_happy__KXO8S7OP.npy
# 1947 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_10__exit_phone_room__BVVPN5D5.npy
# 1948 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_14__outside_talking_still_laughing__8U9ULZDT.npy
# 1949 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_24__walking_down_street_outside_angry__59PN7WZ2.npy
# 1950 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_07__walking_down_street_outside_angry__IKMKYKPG.npy
# An error occurred: object of type 'NoneType' has no len()
# 1951 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/21_12__outside_talking_pan_laughing__ME7E3R1D.mp4
# 1952 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_06__podium_speech_happy__3K21NFNM.npy
# 1953 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_20__hugging_happy__6SUW7063.npy
# 1954 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/13_09__walking_down_indoor_hall_disgust__21H6XSPE.mp4
# 1955 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_03__secret_conversation__L0GHYIFS.npy
# 1956 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_03__exit_phone_room__7JPPCV50.npy
# 1957 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_09__walking_down_street_outside_angry__NDMHWBT1.npy
# 1958 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/19_24__outside_talking_still_laughing__NPZW2Z9L.npy
# 1959 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/01_04__walking_down_street_outside_angry__GBC7ZGDP.npy
# 1960 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/12_03__exit_phone_room__D7G6YJON.npy
# 1961 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_11__exit_phone_room__C8C4FW99.npy
# An error occurred: object of type 'NoneType' has no len()
# 1962 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/06_25__outside_talking_pan_laughing__3QQBVBYN.mp4
# 1963 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_02__outside_talking_still_laughing__Z7FQ69VP.npy
# 1964 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/16_05__walking_down_street_outside_angry__94435UY3.npy
# An error occurred: object of type 'NoneType' has no len()
# 1965 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/06_18__outside_talking_pan_laughing__UIQG2RF4.mp4
# 1966 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/27_26__podium_speech_happy__IE9N0ZI9.npy
# 1967 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_20__exit_phone_room__C50CSOEX.npy
# 1968 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/05_17__talking_against_wall__M3H96PDQ.npy
# 1969 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/02_06__kitchen_pan__3J3BHSHI.npy
# 1970 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/07_06__exit_phone_room__NMGYPBXE.npy
# 1971 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_27__walking_down_street_outside_angry__1KU29EUL.npy
# 1972 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_02__podium_speech_happy__2YSYT2N3.npy
# 1973 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/22_10__secret_conversation__PUJR4HJ1.npy
# 1974 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_04__walk_down_hall_angry__7NW4Z6WZ.npy
# 1975 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/15_12__walking_and_outside_surprised__N0SRODQD.mp4
# 1976 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/09_03__outside_talking_still_laughing__8DTEGQ54.npy
# An error occurred: object of type 'NoneType' has no len()
# 1977 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/13_04__kitchen_pan__00T3UYOR.mp4
# An error occurred: object of type 'NoneType' has no len()
# 1978 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/13_11__kitchen_pan__XXKQ4XM0.mp4
# 1979 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/13_20__kitchen_still__2994SNXH.npy
# 1980 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/22_10__kitchen_still__J2HR5HKH.npy
# 1981 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_06__podium_speech_happy__QRCD27P8.npy
# 1982 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/28_08__secret_conversation__5DCAESDA.npy
# 1983 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_25__walking_down_street_outside_angry__FF95NMIQ.npy
# 1984 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/25_02__outside_talking_pan_laughing__Z7FQ69VP.npy
# An error occurred: object of type 'NoneType' has no len()
# 1985 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/16_08__kitchen_pan__8Q7JCS95.mp4
# 1986 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/12_06__secret_conversation__F3I4PDYF.mp4
# An error occurred: object of type 'NoneType' has no len()
# 1987 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/07_09__outside_talking_pan_laughing__N9CWME71.mp4
# 1988 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/12_07__walking_and_outside_surprised__X9X7FAZG.mp4
# 1989 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/12_02__walking_and_outside_surprised__9D2ZHEKW.mp4
# 1990 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/03_07__walking_outside_cafe_disgusted__WPT3Z2KN.npy
# 1991 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/06_18__talking_against_wall__DEA1TCLN.npy
# 1992 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_11__outside_talking_still_laughing__ALJ0OHNM.npy
# 1993 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/15_07__exit_phone_room__UGGRZJ60.npy
# 1994 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/26_03__talking_against_wall__WBSXBL82.npy
# 1995 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/10_19__exit_phone_room__O2IKR6YM.npy
# 1996 => File processed:  /content/drive/MyDrive/Dissertation/dataset/manipulated_sequences/DeepFakeDetection/c40/videos/20_14__walking_and_outside_surprised__B014BKVO.mp4
# 1997 => File missed:  /content/drive/MyDrive/Dissertation/deepfake-detection-using-esn/out/0/14_18__walking_outside_cafe_disgusted__6SB2BR0A.npy
